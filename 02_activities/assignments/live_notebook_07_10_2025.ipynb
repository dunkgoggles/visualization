# %%
# !pip install matplotlib-venn wordcloud
# Out:
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.2.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.8.4)
# Requirement already satisfied: numpy in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.24.3)
# Requirement already satisfied: scipy in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.9.1)
# Requirement already satisfied: pillow in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib-venn) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\scott\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl (300 kB)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45437 sha256=ab0f96e4b0ac82368fe2546bc83dbe3fc26858857768bfb39d214dd0aeff11c8
#   Stored in directory: c:\users\scott\appdata\local\pip\cache\wheels\86\29\d8\0f3c5a37c967a34fb40aaabd414f92104d2ad5fb149c0114a1
# Successfully built matplotlib-venn
# Installing collected packages: wordcloud, matplotlib-venn
# Successfully installed matplotlib-venn-1.1.2 wordcloud-1.9.4

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy 
import PIL
import requests

np.random.seed(613)

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('whitegrid')

sns.lineplot(data=tips,
             x='total_bill',
             y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('whitegrid')

fig = plt.subplots(figsize=(10,3))

tipgraph = sns.lineplot(data=tips,
             x='total_bill',
             y='tip',
             color = 'hotpink',
             linestyle = '--',
             linewidth = 3,
             marker = 'o',
             markerfacecolor = 'indigo')

tipgraph.set(title = 'Tip Vs. Total Bill',
             xlabel = 'Total Bill ($)',
             ylabel = 'Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tip Vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
                           y='tip', 
                           style = 'time',
                           hue = 'day',
                           palette = ['purple','hotpink','deepskyblue','yellowgreen'])

tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel = 'Tip Amount($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount($)')]

# %%
sns.pairplot(data = tips,
             hue = 'day')

# %%
daysplot = sns.relplot(data=tips,
                       x="total_bill",
                       y="tip",
                       hue="sex",
                       col="day",
                       kind="scatter",
                       col_wrap=2)

# %%
import plotly.graph_objects as go

x1 = np.array(["Luffy", "Zorro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph = go.Figure()

graph.add_trace(go.Bar(x=x1, y=y1))

graph.update_layout(title="Pirate Scores",
                    xaxis_title="Pirates",
                    yaxis_title="Score")

graph.show()

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, 
                           mode = 'markers',
                           marker = dict(size = 15,
                                       color = 'hotpink',
                                       opacity=1,
                                       line = dict(width = 5,
                                                   color='purple'))))

graph.update_layout(title='Interactive Pirate Plot',
                    xaxis_title='Pirates',
                    yaxis_title='Scores',
                    width=500, height=500)

graph.show()

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
                 on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
#Join all text from each row from quote column into a string

text = " ".join(each for each in df.quote)

#Generate wordcloud image

WordCloud = WordCloud(background_color="white",
                      colormap = 'inferno').generate(text)

#Use matplotlib syntax to put our image in a figure

fig, ax = plt.subplots(figsize=(7,3))
ax.imshow(WordCloud,
          interpolation='bilinear') #This line helps smooth the image
ax.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue", "red"),
                           alpha=0.5)

plt.show()

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2([A,B],
                set_labels = ('Fruits', 'Pies'),
                set_colors=("blue", "red"),
                alpha=0.5)


diagram.get_label_by_id("10").set_text("\n".join(A-B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))
